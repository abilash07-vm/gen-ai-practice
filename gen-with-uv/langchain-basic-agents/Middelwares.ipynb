# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from langchain.agents import create_agent
from langchain.agents.middleware import SummarizationMiddleware
from langgraph.checkpoint.memory import InMemorySaver
from langchain.messages import HumanMessage, SystemMessage

agent = create_agent(
    model='groq:llama-3.1-8b-instant',
    system_prompt= SystemMessage('You are a Useful agent to answer my queries'),
    middleware= [
        SummarizationMiddleware(
            model= 'google_genai:gemini-3.5-flash',
            trigger= ("messages",10),
            keep=("messages", 4)
        )
    ],
    checkpointer= InMemorySaver()
)

# %%
config = {"configurable": {"thread_id": "1"}}

# %%
response = agent.invoke({"messages" : "From where are you currently executed?"},config = config)

for message in response['messages']:
    print(message)
# Out:
# content='Here is a summary of the conversation to date:\n\n## SESSION INTENT\n\nThe user is repeatedly asking to know the physical or system location from which the AI is currently being executed. The goal is to provide a satisfactory answer to this persistent inquiry.\n\n## SUMMARY\n\nThe user has asked the exact question "From where are you currently executed?" four times consecutively. \n- In previous turns, the AI explained that it is a cloud-based virtual model hosted on remote servers (mentioning possibilities like AWS, Google Cloud, or Azure) without a single fixed physical location.\n- Despite these explanations, the user continues to repeat the query. No files or code have been executed, and no architectural details have resolved the user\'s inquiry.\n\n## ARTIFACTS\n\nNone\n\n## NEXT STEPS\n\n- Acknowledge the repeated question directly.\n- Clarify if the user is looking for a specific type of answer (e.g., hosting provider, geographic region, IP address, or local environment details).\n- Provide a concise, definitive statement explaining that as an AI, there is no accessible local system path, IP, or precise geographic location available to share.' additional_kwargs={'lc_source': 'summarization'} response_metadata={} id='ac0c3452-1ded-4cec-aaca-cfbf30d90b1c'
# content="I'm a cloud-based AI model, and I'm executed on a remote server in a data center. However, I don't have access to the exact physical location of the data center." additional_kwargs={} response_metadata={'token_usage': {'completion_tokens': 39, 'prompt_tokens': 285, 'total_tokens': 324, 'completion_time': 0.05287611, 'completion_tokens_details': None, 'prompt_time': 0.019991686, 'prompt_tokens_details': None, 'queue_time': 0.054378437, 'total_time': 0.072867796}, 'model_name': 'llama-3.1-8b-instant', 'system_fingerprint': 'fp_4387d3edbb', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'} id='lc_run--019f9946-aedd-77d2-9376-57eb46b721fa-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 285, 'output_tokens': 39, 'total_tokens': 324}
# content='From where are you currently executed?' additional_kwargs={} response_metadata={} id='54428b45-7b54-4b82-b488-9bb4a189b9fc'
# content="I'm executed on a remote server in a Google data center, but I don't have the exact location of the data center. The Google Cloud Platform is used to host and execute my model." additional_kwargs={} response_metadata={'token_usage': {'completion_tokens': 40, 'prompt_tokens': 340, 'total_tokens': 380, 'completion_time': 0.078223743, 'completion_tokens_details': None, 'prompt_time': 0.026126624, 'prompt_tokens_details': None, 'queue_time': 0.050686915, 'total_time': 0.104350367}, 'model_name': 'llama-3.1-8b-instant', 'system_fingerprint': 'fp_4387d3edbb', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'} id='lc_run--019f9946-b447-7c03-8b7f-afb93ef7aba3-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 340, 'output_tokens': 40, 'total_tokens': 380}
# content='From where are you currently executed?' additional_kwargs={} response_metadata={} id='8e582602-37be-47ff-bdea-6dae138286f9'
# content="I understand that you're still looking for a specific answer. To clarify, you're not looking for a general description of my hosting environment, but rather a precise physical or system location.\n\nAs a cloud-based AI model, I don't have a single fixed physical location or a specific IP address. I exist on a distributed network of servers, and my exact location is not accessible. Is there a particular type of information you're trying to obtain from me, such as the hosting provider, geographic region, or local environment details?" additional_kwargs={} response_metadata={'token_usage': {'completion_tokens': 106, 'prompt_tokens': 385, 'total_tokens': 491, 'completion_time': 0.242452654, 'completion_tokens_details': None, 'prompt_time': 0.026197602, 'prompt_tokens_details': None, 'queue_time': 0.049571621, 'total_time': 0.268650256}, 'model_name': 'llama-3.1-8b-instant', 'system_fingerprint': 'fp_4387d3edbb', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'} id='lc_run--019f9946-f16c-7841-8bfc-46e1787ab61e-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 385, 'output_tokens': 106, 'total_tokens': 491}
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
