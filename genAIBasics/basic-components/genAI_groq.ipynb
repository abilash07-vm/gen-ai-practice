# %%
from dotenv import load_dotenv

load_dotenv()

import os

groq_api_key = os.getenv('GROQ_API_TOKEN')

# %%
from langchain_groq import ChatGroq

llm = ChatGroq(model='llama-3.1-8b-instant', groq_api_key = groq_api_key)

# %%
result = llm.invoke('How many words are there in English')

# %%
result
# Out:
# AIMessage(content="Estimating the exact number of words in the English language is a challenging task, as it's constantly evolving and new words are being added all the time. However, I can provide you with some approximate numbers based on various sources.\n\nAccording to the Oxford English Dictionary, which is considered one of the most comprehensive dictionaries of the English language, there are approximately 170,000 to 200,000 words in current use. This number includes:\n\n1. Inflected forms of words (e.g., running, runs, runner)\n2. Compound words (e.g., toothbrush, mailbox)\n3. Derived words (e.g., happiness, happinesses)\n4. Colloquialisms, dialectical words, and regional expressions\n5. Technical and specialized terms from various fields (e.g., medicine, law, science)\n\nHowever, if we only consider the core vocabulary, excluding inflected forms, compound words, and derived words, the number of distinct words is estimated to be around 40,000 to 60,000.\n\nOther sources, such as the Global Language Monitor, estimate the number of words in the English language to be around 1 million, but this number includes:\n\n1. Proper nouns (e.g., names of people, places, organizations)\n2. Acronyms and abbreviations\n3. Words from specialized domains (e.g., IT, medicine, finance)\n4. Words from regional or dialectical languages\n\nKeep in mind that these estimates vary widely, and it's difficult to give an exact number. The English language is constantly evolving, and new words are being added all the time.\n\nTo give you an idea of the growth of the English language, here are some approximate numbers of words added to the English language over the years:\n\n* 15th-17th centuries: 10,000-20,000 words added\n* 18th-19th centuries: 30,000-50,000 words added\n* 20th century: 100,000-200,000 words added\n* 21st century: 50,000-100,000 words added (and counting!)\n\nSo, while it's difficult to give an exact number, it's safe to say that there are hundreds of thousands, if not millions, of words in the English language.", additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 468, 'prompt_tokens': 42, 'total_tokens': 510, 'completion_time': 0.596935266, 'completion_tokens_details': None, 'prompt_time': 0.0019537, 'prompt_tokens_details': None, 'queue_time': 0.052188299, 'total_time': 0.598888966}, 'model_name': 'llama-3.1-8b-instant', 'system_fingerprint': 'fp_4387d3edbb', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019de801-79fc-7561-874c-41777789a2f8-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 42, 'output_tokens': 468, 'total_tokens': 510})
