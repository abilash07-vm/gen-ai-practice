# %%
from langchain_community.document_loaders import TextLoader

txt_loader = TextLoader('../../sample_files/text/book_chapter_excerpt.txt')

# %%
data = txt_loader.load()
data
# Out:
# [Document(metadata={'source': '../sample files/text/book_chapter_excerpt.txt'}, page_content='Book Chapter Excerpt\n\nChapter 4 discusses information retrieval systems and how ranking quality depends on indexing,\nquery understanding, document representation, and evaluation metrics such as precision and recall.\n')]

# %%
from langchain_community.embeddings import OllamaEmbeddings

embedding = OllamaEmbeddings(model='embeddinggemma:latest')
# Out:
# C:\Users\abila\AppData\Local\Temp\ipykernel_16556\2602943748.py:3: LangChainDeprecationWarning: The class `OllamaEmbeddings` was deprecated in LangChain 0.3.1 and will be removed in 1.0.0. An updated version of the class exists in the `langchain-ollama package and should be used instead. To use it run `pip install -U `langchain-ollama` and import as `from `langchain_ollama import OllamaEmbeddings``.
#   embedding = OllamaEmbeddings(model='embeddinggemma:latest')

# %%
embded_data = embedding.embed_documents(data)

len(embded_data[0])
# Out:
# 1

# %%
len(embded_data[0])
# Out:
# 768
